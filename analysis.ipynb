# %%
import pandas as pd

filepaths = '강원특별자치도 춘천시_의류수거함 현황_20240130.csv'

try:
    data = pd.read_csv(filepaths, encoding='utf-8')
except:
    data = pd.read_csv(filepaths, encoding='cp949')

data.head(94)
# Out:
#       연번        설치년월  읍면동                         도로명주소  \
# 0    1.0  2023-04-10  우두동      강원특별자치도 춘천시 충열로16번길 13-8
# 1    2.0  2023-04-10  퇴계동       강원특별자치도 춘천시 춘주로201번길 17
# 2    3.0  2023-04-10  근화동      강원특별자치도 춘천시 공지로 451번길 16
# 3    4.0  2023-04-10  소양동         강원특별자치도 춘천시 소양로 190번길
# 4    5.0  2023-04-10  온의동  강원특별자치도 춘천시 온의동 산26 (534-9호)
# ..   ...         ...  ...                           ...
# 89  90.0  2023-04-10  신동면             강원특별자치도 춘천시 삼포길67
# 90  91.0  2023-04-10  신동면         강원특별자치도 춘천시 증리 1041-1
# 91  92.0  2023-04-10  신동면         강원특별자치도 춘천시 팔미리 267-3
# 92  93.0  2023-04-10   동면            강원특별자치도 춘천시 가산로 45
# 93  94.0  2023-04-10   동면        강원특별자치도 춘천시 동면 길골길 224
#
#                             지번주소          상세위치      데이터기준일
# 0         강원특별자치도 춘천시 우두동 1063-3           NaN  2024-01-30
# 1          강원특별자치도 춘천시 퇴계동 900-1           NaN  2024-01-30
# 2         강원특별자치도 춘천시 근화동 283-12           NaN  2024-01-30
# ...
